# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('HousingData.csv')
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# std     27.999513    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.175000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     76.800000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     93.975000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  486.000000  506.000000
# mean    12.715432   22.532806
# std      7.155871    9.197104
# min      1.730000    5.000000
# 25%      7.125000   17.025000
# 50%     11.430000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
df.shape
# Out:
# (506, 14)

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
sns.displot(df['MEDV'],bins=30)
plt.show()

# %%
# %matplotlib inline
# plt.scatter(df.)


df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# std     27.999513    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.175000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     76.800000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     93.975000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  486.000000  506.000000
# mean    12.715432   22.532806
# std      7.155871    9.197104
# min      1.730000    5.000000
# 25%      7.125000   17.025000
# 50%     11.430000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
# x=df.~MEDV
b='MEDV'
x=df.loc[ :, df.columns!=b]
y=df['MEDV']

from sklearn.model_selection import train_test_split

# %%
x_train ,x_test, y_train, y_test = train_test_split(
        x, y, test_size=0.2, random_state=0)

# %%
# "xtrain : ", x_train
x_train
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 220   0.35809   0.0   6.20   1.0  0.507  6.951  88.5  2.8617    8  307
# 71    0.15876   0.0  10.81   0.0  0.413  5.961  17.5  5.2873    4  305
# 240   0.11329  30.0   4.93   NaN  0.428  6.897  54.3  6.3361    6  300
# 6     0.08829  12.5   7.87   NaN  0.524  6.012  66.6  5.5605    5  311
# 417  25.94060   0.0  18.10   0.0  0.679  5.304  89.1  1.6475   24  666
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 323   0.28392   0.0   7.38   0.0  0.493  5.708  74.3  4.7211    5  287
# 192       NaN  45.0   3.44   0.0  0.437  7.178  26.3  6.4798    5  398
# 117   0.15098   0.0  10.01   0.0  0.547  6.021  82.6  2.7474    6  432
# 47    0.22927   0.0    NaN   0.0  0.448  6.030  85.5  5.6894    3  233
# 172   0.13914   0.0   4.05   0.0  0.510  5.572  88.5  2.5961    5  296
#
#      PTRATIO       B  LSTAT
# 220     17.4  391.70   9.71
# 71      19.2  376.94   9.88
# 240     16.6  391.25  11.38
# 6       15.2  395.60  12.43
# 417     20.2  127.36  26.64
# ..       ...     ...    ...
# 323     19.6  391.13  11.74
# 192     15.2  390.49   2.87
# 117     17.8  394.51  10.30
# 47      17.9  392.74  18.80
# 172     16.6  396.90  14.69
#
# [404 rows x 13 columns]

# %%
x_test
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 329   0.06724   0.0   3.24   0.0  0.460  6.333   17.2  5.2146    4  430
# 371   9.23230   0.0  18.10   0.0  0.631  6.216  100.0  1.1691   24  666
# 219   0.11425   0.0    NaN   1.0  0.550  6.373   92.4  3.3633    5  276
# 403  24.80170   0.0  18.10   0.0  0.693  5.349   96.0  1.7028   24  666
# 78    0.05646   0.0  12.83   0.0  0.437  6.232   53.7  5.0141    5  398
# ..        ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 56    0.02055  85.0   0.74   0.0  0.410  6.383   35.7  9.1876    2  313
# 455   4.75237   0.0  18.10   0.0  0.713  6.525   86.5  2.4358   24  666
# 60    0.14932  25.0   5.13   0.0  0.453  5.741   66.2  7.2254    8  284
# 213   0.14052   0.0  10.59   0.0  0.489  6.375   32.3  3.9454    4  277
# 108   0.12802   0.0   8.56   0.0  0.520  6.474   97.1  2.4329    5  384
#
#      PTRATIO       B  LSTAT
# 329     16.9  375.21   7.34
# 371     20.2  366.15   9.53
# 219     16.4  393.74  10.50
# 403     20.2  396.90  19.77
# 78      18.7  386.40  12.34
# ..       ...     ...    ...
# 56      17.3  396.90   5.77
# 455     20.2   50.92  18.13
# 60      19.7  395.11  13.15
# 213     18.6  385.81   9.38
# 108     20.9  395.24  12.27
#
# [102 rows x 13 columns]

# %%
y_train
# Out:
# 220    26.7
# 71     21.7
# 240    22.0
# 6      22.9
# 417    10.4
#        ...
# 323    18.5
# 192    36.4
# 117    19.2
# 47     16.6
# 172    23.1
# Name: MEDV, Length: 404, dtype: float64

# %%
y_train.isnull().sum()
# Out:
# 0

# %%
y_test
# Out:
# 329    22.6
# 371    50.0
# 219    23.0
# 403     8.3
# 78     21.2
#        ...
# 56     24.7
# 455    14.1
# 60     18.7
# 213    28.1
# 108    19.8
# Name: MEDV, Length: 102, dtype: float64

# %%
#train model
from sklearn.linear_model import LinearRegression

# %%
x_train.isnull().sum()
# Out:
# CRIM       14
# ZN         16
# INDUS      16
# CHAS       17
# NOX         0
# RM          0
# AGE        15
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      19
# dtype: int64

# %%
# x_train=x_train.dropna()
x_train=x_train.fillna(0)
x_train.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %%
# x_test.isnull().sum()
x_test=x_test.fillna(0)

# %%
x_test.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %%
regressor= LinearRegression()
regressor.fit(x_train,y_train)


y_pred= regressor.predict(x_test)

# %%
plt.scatter(y_test,y_pred,c='red')
plt.xlabel('price')
plt.ylabel('predicted value')
plt.title('oroginal price vs predicted price :Linear regression')
plt.show()

# %%
#kitna error he, error metric

from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)

# %%
y_test
# Out:
# 329    22.6
# 371    50.0
# 219    23.0
# 403     8.3
# 78     21.2
#        ...
# 56     24.7
# 455    14.1
# 60     18.7
# 213    28.1
# 108    19.8
# Name: MEDV, Length: 102, dtype: float64

# %%
y_pred
# Out:
# array([25.89653238, 21.68485195, 29.43914053, 11.05969774, 21.38048175,
#        18.64896728, 19.69723035, 20.85079459, 18.83211902, 19.13545194,
#         3.28932028, 16.0108609 , 16.63048131,  5.3434315 , 38.58733303,
#        33.075127  , 21.34393783, 37.02201628, 31.11764174, 23.02435699,
#        24.34058907, 23.17687935, 20.43001111, 30.31392204, 22.4187548 ,
#         7.10059589, 17.08320361, 17.64428292, 35.43610419, 21.00885015,
#        17.55130798, 16.99662257, 18.87962502, 23.77611988, 31.25601243,
#        18.78290516, 11.44777829, 23.01889118, 18.0872106 , 15.60201098,
#        26.20331261, 21.54194601, 23.04868112, 14.40484901, 23.51083888,
#        24.37605981, 20.84387307, 22.98366867, 11.11098427, 23.87412466,
#        23.56879563, 18.91825234, 24.17065315, 30.88422778, 12.46125027,
#        22.66004063, 21.3278747 , 15.73940328, 10.69138336, 22.26817398,
#        17.91391243, 21.67488518, 31.82690142, 31.18660098, 17.10568629,
#        32.86651454, 21.23902675, 20.25787447, 20.63119893, 23.32628143,
#        22.36676294, 23.72222898, 30.56802159, 29.21707638, 24.37019513,
#         6.06288216, 38.55281967, 23.66937305, 27.18640213, 19.3085267 ,
#        28.45446945, 18.34679059, 21.05329159, 37.47907319, 39.09862125,
#        23.61002106, 24.94203394, 16.8748858 , 24.70256225, 16.56582129,
#        16.38632355, 13.48259726, 24.28241987, 30.97402877, 23.24587388,
#        20.10067655,  1.58480967, 25.10500864, 15.31727554, 17.34126411,
#        25.52891242, 21.81815341])

# %%
regressor.intercept_
# Out:
# 33.69826707206866

# %%
regressor.coef_
# Out:
# array([-1.37224376e-01,  4.00295624e-02, -6.41184695e-02,  2.78772982e+00,
#        -1.44591348e+01,  4.31073421e+00, -2.91064226e-02, -1.43688327e+00,
#         2.01719678e-01, -9.00023176e-03, -1.06492710e+00,  8.82669613e-03,
#        -3.39429892e-01])

# %%
#training accuracy
regressor.score(x_train,y_train)
# Out:
# 0.7622885711926607

# %%
# testing accuracy 
regressor.score(x_test,y_test)
# Out:
# 0.5520236888639354
